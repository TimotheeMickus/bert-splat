# %%
import seaborn as sns
import numpy as np
sns.set(rc={'figure.figsize':(10,10)})

# %%
def heat_me_up_scotty(matrix_dump): # 'f1-classif-semcor.npy'

    data = np.load(matrix_dump)
    mask = np.triu(data)
    data = data[1:,:-1]
    mask = mask[1:,:-1]

    keys_in_order = [
        ('I',), ('H',), ('F',), ('C',),
        ('I', 'H'), ('I', 'F'), ('I', 'C'), ('H', 'F'), ('H', 'C'), ('F', 'C'),
        ('I', 'H', 'F'), ('I', 'H', 'C'),  ('I', 'F', 'C'), ('H', 'F', 'C'),
        ('I', 'H', 'F', 'C')
    ]

    labels = ["+".join(l) for l in keys_in_order]

    sns.heatmap(data, vmin=0, vmax=1, annot=True, square=True, xticklabels=labels[:-1], yticklabels=labels[1:], cmap="flare", mask=mask)

# %%
heat_me_up_scotty('f1-classif-semcor.npy')

# %%
heat_me_up_scotty('f1-knn5-semcor.npy')

# %%
heat_me_up_scotty('f1-classif-ritter-untuned.npy')

# %%
heat_me_up_scotty('f1-classif-ritter-tuned.npy')
